# %% [markdown]
# ## Arrays.
#
# An array is a one-dimensional data-structure consisting of a collection of elements of the same data-type.

# %% [markdown]
# ![arrays_001.png](attachment:arrays_001.png)

# %% [markdown]
# For example, we can create a `numpy.array` called `a` and store `10` **integers** in it.

# %%
import numpy as np

a = np.array([23,15,86,65,50,41,72,9,91,11])
a
# Out:
# array([23, 15, 86, 65, 50, 41, 72,  9, 91, 11])

# %% [markdown]
# Each element in the array can be efficiently located by its **index**. `numpy.array` indexes start from `0`. So, the first element of the array can be directly accessed using `a[0]`, the second element of the array can be directly accessed using `a[1]`. Elements of an array can be directly accessed using the array index. Accessing any element of the array (no matter how long it is) can be done in $O(1)$ time.

# %%
for i in range(len(a)):
    print(f"a[{i}] = {a[i]}")
# Out:
# a[0] = 23
# a[1] = 15
# a[2] = 86
# a[3] = 65
# a[4] = 50
# a[5] = 41
# a[6] = 72
# a[7] = 9
# a[8] = 91
# a[9] = 11

# %% [markdown]
# This is possible because, in computer memory, elements of an array are stored in continguous (consecutive) memory locations. Arrays occupy a single-continuous slab(block) of memory in the RAM.
#
# For example, one `int` occupies $4$ bytes. An array of $10$ ($4$-byte) integer variables, with indices $0$ through $9$ may be stored at memory addresses $2000$, $2004$, $\ldots$, $2036$. So the element with index $i$ has the address $2000 + (i \times 4)$.
#
# An array is stored so that the address of each element can be computed from its **index**.

# %% [markdown]
# **Arrays are fixed-size containers**. Once an array of $10$ `int`'s has been allocated, an $11$th element cannot be added to this array `a`.  Arrays in most programming languages, have to be declared in advance; therefore, their sizes have to be known
# before the program starts. This means that the programmer needs a fair knowledge of the problem being programmed to choose the right size for the array. If the size is too big, then the array unnecessarily occupies memory space, which is basically
# wasted. If the size is too small, the array can overflow with data and the program will abort.

# %% [markdown]
# ---
# **Definition**. An array is a
#
# - fixed-size container
# - that occupies contiguous memory locations
# - that can be used to store a collection of elements of the same data-type
# - and can be accessed using an array index.
#
# ---

# %% [markdown]
# `numpy` arrays support negative indices.

# %% [markdown]
# ![arrays_002.png](attachment:arrays_002.png)

# %% [markdown]
# ## Insertion Sort.
#
# Our first algorithm, insertion sort, solves the sorting problem.
#
# **Input** : A sequence of numbers $[a_0,a_1,\ldots,a_{n-1}]$.
#
# **Output** : A permutation (reordering) of numbers $[a_0',a_1',\ldots,a_{n-1}']$ of the input sequence such that
# $$a_1' \leq a_2' \leq \ldots \leq a_n'$$

# %% [markdown]
# We start with **insertion sort**, which is an efficient algorithm for sorting a small number of elements. Insertion sort works the way many people sort a hand of playing cards. We start with an empty left-hand and the cards face down on the table. We then remove one card at a time from the table and insert it into the correct position in the left hand. To find the correct position for a card, we compare it with each of the cards already in the hand, from right to the left, as illustrated in the figure. At all times, the cards held in the left hand are sorted, and these cards were originally the top cards of the pile on the table.

# %% [markdown]
# ![arrays_003.PNG](attachment:arrays_003.PNG)

# %% [markdown]
# We present our code for insertion sort as a function `insertionSort(A)` which takes as a parameter an array `A[0..n-1]` of $n$ elements that is to be sorted. The algorithm sorts the input numbers in place: it rearranges the numbers within the array $A$.

# %% [markdown]
# ![arrays_004.PNG](attachment:arrays_004.PNG)

# %%
def insertionSort(A):
    for j in range(1,len(A)):
        key = A[j]
        
        # Insert A[j] into the sorted sequence A[0..j-1]
        i = j-1
        while i >= 0 and A[i] > key:
            A[i + 1] = A[i]
            i = i - 1
        A[i+1] = key
        
    return A

# %%
A = np.array([5,2,4,6,1,3])
insertionSort(A)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# The figure shows how this algorithm works for `A = np.array([5,2,4,6,1,3])`. The index $j$ indicates the current card being inserted into the hand. At the beginning of each iteration of the `for` loop, which is indexed by $j$, the subarray consisting of the elements $A[0..j-1]$ constitutes the currently sorted hand, and the remaining subarray $A[j+1..n-1]$ corresponds to the pile of cards still on the table. In fact, $A[0..j-1]$ are the elements *originally* in the positions $0$ through $j-1$, but now in sorted order.

# %% [markdown]
# ### Why does insertion sort work?
#
# We prove this using mathematical induction.
#
# **Initialization** : At initialization, the variable $j$ equals $1$. The subarray $A[0..j-1] = A[0]$ consists of a single element and a singleton array is always sorted.
#
# **Maintenance** : Consider the $j$th iteration of the array. Assume that `A[0..j-1]` is sorted. We pull out the element `A[j]` and call it `key`. We are basically interested to find the proper position in the subarray `A[0..j-1]` for inserting the `key`. To insert the `key`, we must create vacant space for it, in the subarray `A[0..j-1]`. Thus, beginning with `A[j-1]`, we start shifting the elements to the right, one element at a time, by copying `A[j-1]` to `A[j]`, `A[j-2]` to `A[j-1]`, `A[j-3]` to `A[j-2]`. We set `i = j-1` and copy `A[i]` to `A[i+1]`. This process continues, until an element `A[i]` is found that is smaller than the `key` or we reach the end and no such element could be found (`i = -1`). In both cases, the `key` should be copied to `A[i+1]`. It is imperative, that the subarray `A[0..j]` is sorted after the $j$th iteration.
#
# **Termination** : Finally we examine what happens when the loop terminates. The condition causing the `for` loop to terminate is that `j > len(A)-1`. Because each loop iteration increases $j$ by $1$, we must have $j = n$ at that time. Substituting $n$ for $j$, we have that, at the end of the $(n-1)$st iteration, the subarray `A[0..n-1]` consists of the elements originally in `A[0..n-1]`, but in the sorted order. Observe that, `A[0..n-1]` is the entire array, we conclude that the entire array is sorted.

# %% [markdown]
# ## Merge Sort
#
# We can choose from a wide range of design techniques. For insertion sort, we used an **incremental** approach : having sorted the subarray `A[0..j-1]` we inserted the single element `A[j]` into its proper place yielding the sorted subarray `A[0..j]`. In this section we examine an alternative design approach, known as divide-and-conquer. We'll use divide and conquer approach to design a sorting algorithm.
#
# In the divide-and-conquer approach, we typically break the problem into several sub-problems that are similar to the original problem, but smaller in size, solve the subproblems recursively, and then combine these solutions to create a solution to the original problem.
#
# **Divide** the problem into a number of subproblems that are smaller instances of the same problem.
#
# **Conquer** the subproblems by solving them recursively. If the sub-problem sizes are small enough, however, just solve the subproblems in a straightforward manner.
#
# **Combine** the solutions to the subproblems into the solution for the original problem.
#
# The **merge sort** algorithm closely follows the divide-and-conquer paradigm. Intuitively, it operates as follows:
#
# **Divide**: Divide the $n$-element sequence to be sorted into two subsequences of $n/2$ elements each.
#
# **Conquer**: Sort the two subsequences recursively using merge sort.
#
# **Combine**: Merge the two sorted subsequences to produce the sorted answer.
#
# The recursion bottoms out when the sequence to be sorted has length $1$, in which case there is no work to be done, since every sequence of length $1$ is already in sorted order.
#
# The key operation of the merge sort algorithm is the merging of two sorted sequences in the "combine" step. We merge by calling an auxiliary function `merge(L,R)` where `L` and `R` are two sorted lists. The algorithm merges them to form a single sorted list.

# %%
def merge(L,R):
    n1 = len(L)
    n2 = len(R)
    result = np.zeros(n1 + n2)
    
    i = 0
    j = 0
    k = 0
    while (i < n1 and j < n2):
        if L[i] <= R[j]:
            result[k] = L[i]
            i = i + 1
        else:
            result[k] = R[j]
            j = j + 1
        k = k + 1
        
    while (i < n1):
        result[k] = L[i]
        i = i + 1
        k = k + 1
    
    while (j < n2):
        result[k] = R[j]
        j = j + 1
        k = k + 1
        
    return result

# %%
L = np.array([2,4,5,7])
R = np.array([1,2,3,6])
merge(L,R)
# Out:
# array([1., 2., 2., 3., 4., 5., 6., 7.])

# %% [markdown]
# ![arrays_005.png](attachment:arrays_005.png)

# %% [markdown]
# We traverse through the left and right sub-arrays iteratively. Think of `L[i]` and `R[j]` as pointers into the left and right sub-arrays. Each time, we compare an element of the left-subarray with an element of the right sub-array and store the smaller of the two in the result. We then increment the appropriate pointer.
#
# If we reach the end of one of the lists, we must store all remaining elements of the other list into `result`.

# %% [markdown]
# We can now use the `merge(L,R)` function in the merge sort algorithm. The function `mergeSort(A)` sorts the elements in the sub-array `A`. If the number of elements $n \leq 1$, then the subarray has atmost one element and is therefore already sorted. Otherwise, the divide step simply computes an index `q` that partitions `A` into two subarrays : `A[0..q]` containing `floor(n/2)` and `A[q+1..]` containing `ceil(n/2)` elements.

# %%
import math

def mergeSort(A):
    n = len(A)

    if n <= 1:
        return A
    
    q = n//2 - 1

    L = mergeSort(A[0:q+1])
    R = mergeSort(A[q+1:])
    return merge(L,R)

# %%
A = np.array([5,2,4,7,1,2,3,6])
mergeSort(A)
# Out:
# array([1., 2., 2., 3., 4., 5., 6., 7.])

# %% [markdown]
# ## Linear Search and Binary Search
#
# The operation of searching involves locating a given element `x` in an array `A`. One of the simplest ideas is to do a linear traversal and iterate through the array, until the element is found.

# %%
def linearSearch(A,x):
    n = len(A)
    
    for i in range(n):
        if A[i] == x:
            break;
    
    if i > n:
        return False, -1
    else:
        return True, i

# %%
A = np.array([5,2,4,6,2,7,1,3])
linearSearch(A,1)
# Out:
# (True, 6)

# %% [markdown]
# If we have a sorted array $S$, we can perform **binary search** to locate an element called `key` in the array. The middle element of the array is pulled out and stored in an element `mid`. Since the array is sorted, `if key <= mid`, then the element is likely to be found in the left-half subarray. Else, `if key > mid`, then the element is likely to be found in the right-half. Binary search is then performed recursively on either left-half or right-half of the original array.

# %%
def binarySearch(S,key, p, q):
    
    if p >= q:
        if key == S[p]:
            return True, p
        else:
            return False, -1
    
    m = (p + q)//2
    mid = S[m]
    
    if (key <= mid):
        q = m
        return binarySearch(S,key,p,q)
    else:
        p = m + 1
        return binarySearch(S,key,p,q)

# %%
S = np.array([1,4,9,16,25,36,49,64,81,100])
binarySearch(S,81,0,9)
# Out:
# (True, 8)

# %% [markdown]
# **Exercise problem 1**. For each of the following problems, give an algorithm that finds the desired numbers within the given amount of time. To keep your answers brief, feel free to use algorithms from the book as subroutines. For the example, S = {6, 13, 19, 3, 8}, 19 − 3 maximizes the difference, while 8 − 6 minimizes the difference.
#
# (a) Let S be an unsorted array of n integers. Give an algorithm that finds the pair x, y ∈ S that maximizes $|x − y|$. Your algorithm must run in O(n) worst-case time.
#
# (b) Let S be a sorted array of n integers. Give an algorithm that finds the pair x, y ∈ S that maximizes $|x − y|$. Your algorithm must run in O(1) worst-case time.
#
# (c) Let S be an unsorted array of n integers. Give an algorithm that finds the pair x, y ∈ S that minimizes $|x − y|$, for $x \neq y$. Your algorithm must run in O(n log n) worst-case time.
#
# (d) Let S be a sorted array of n integers. Give an algorithm that finds the pair x, y ∈ S that minimizes $|x − y|$, for $x \neq y$. Your algorithm must run in O(n) worst-case time.

# %%
# Solution.

# 1(a)

def findPair(A):
    
    biggestElement = A[0]
    smallestElement = A[0]
    
    for i in range(1,len(A)):
        if A[i] >= biggestElement:
            biggestElement = A[i]
            
        if A[i] < smallestElement:
            smallestElement = A[i]
    
    return smallestElement, biggestElement

# %%
S = np.array([6,13,19,3,8])
findPair(S)
# Out:
# (3, 19)

# %%
# 1(b)

def findPair2(S):
    n = len(S)
    return S[0], S[n-1]

# %%
# 1(c)
def findMinPair(A):
    B = mergeSort(A)
    
    n = len(B)
    
    if n == 1:
        return B[0], B[0]
    elif n == 2:
        return B[0], B[1]
    else:
        x = B[0]
        y = B[1]
        
        for i in range(1,len(B)-1):
            if abs(B[i+1] - B[i]) < abs(y - x):
                x = B[i]
                y = B[i+1]
        
        return x,y

# %%
A = np.array([6,13,19,3,8])
findMinPair(A)
# Out:
# (6.0, 8.0)

# %% [markdown]
# 1(d). The solution to this problem is simply the function `findMinPair(A)` but without requiring initial sorting of the array.

# %% [markdown]
# **Exercise problem 2.** Given two sets $S_1$ and $S_2$ (each of size $n$), and a number $x$, describe an $O(n \log n)$ algorithm for finding whether there exists a pair of elements, one from $S_1$ and one from $S_2$, that add up to $x$. (For partial credit, give a $\Theta(n^2)$ algorithm for this problem.)

# %%
# This is a naive O(n^2) approach. We check for all possible n^2 pairs.
def sumPair(S1, S2, x):
    pairFound = False
    
    for i in range(0,len(S1)):
        y = x - S1[i]
        
        for j in range(0,len(S2)):
            if y == S2[j]:
                pairFound = True
                break
        
        if pairFound:
            break
    
    return pairFound

# %%
S1 = np.array([6,4,2,3])
S2 = np.array([8,1,12,10])

sumPair(S1,S2,9), sumPair(S1,S2,16)
# Out:
# (False, True)

# %%
# This takes O(n lg n) time.

def sumPair2(S1, S2, x):
    pairFound = False
    
    S1 = np.sort(S1)
    S2 = np.sort(S2)
    
    if S1[0] > x or S2[0] > x:
        return False
    
    for i in range(len(S1)):
        y = S1[i] - x
        
        elementFound,_ =

# %% [markdown]
# **Exercise problem 3.** Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
# https://leetcode.com/problems/two-sum/
#
# Explanation of the solution : https://www.code-recipe.com/post/two-sum
#
# ```
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# ```

# %%
# Naive approach - n^2 comparisons in the worst case.

class Solution:
    def twoSum(self, nums,target):
        for i in range(len(nums)):
            for j in range(i+1,len(nums)):
                if nums[i] + nums[j] == target:
                    return [i,j]
                
        return []

# %%
solution = Solution()
solution.twoSum([2,7,11,15],9)
# Out:
# [0, 1]

# %%
import sys

class Solution:
    def twoSum(self, nums, target):
        
        my_dict = {}
        for i in range(len(nums)):
            if nums[i] in my_dict:
                my_dict[nums[i]].append(i)
            else:
                my_dict[nums[i]] = [i]
        
        
        nums.sort()
        
        i = 0
        j = len(nums) - 1
        
        idx1 = -1
        idx2 = -1
        
        while(i < j):

            sum = nums[i] + nums[j]
            
            if sum > target:
                j = j - 1  
            elif sum < target:
                i = i + 1   
            elif sum == target:
                idx1 = my_dict[nums[i]][0]
                
                if nums[i] == nums[j]:
                    idx2 = my_dict[nums[i]][1]
                else:
                    idx2 = my_dict[nums[j]][0]
            
                return[idx1, idx2]
        
        return []

# %%
solution = Solution()
solution.twoSum([3,2,4],6)
# Out:
# [1, 2]

# %%
solution.twoSum([3,3],6)
# Out:
# [0, 1]

# %%
target = 18
twoSum(nums,target)
# Out:
# False

# %% [markdown]
# **Exercise problem 4.** Give an efficient algorithm to compute the union of sets A and B, where $n = max(|A|, |B|)$. The output should be an array of distinct elements that form the union of the sets, when they appear more than once in the union.
# Assume that $A$ and $B$ are unsorted. Give an $O(n \log n)$ algorithm for the problem.

# %%
def unionOfSets(A,B):
    A = np.sort(A)
    B = np.sort(B)
    S = np.zeros(len(A) + len(B))
    
    i = 0
    j = 0
    k = 0
    
    while(i < len(A) and j < len(B)):
        
        if A[i] < B[j]:
            S[k] = A[i]
            i = i + 1  
            
        elif A[i] > B[j]:
            S[k] = B[j]
            j = j + 1  
            
        elif A[i] == B[j]:
            S[k] = A[i]
            i = i + 1
            j = j + 1
        
        k = k + 1
    
    while (i < len(A)):
        S[k] = A[i]
        i = i + 1
        k = k + 1
        
    while (j < len(B)):
        S[k] = B[j]
        j = j + 1
        k = k + 1
        
    return S[0:k]

# %%
A = np.array([7, 1, 5, 2, 3, 6])
B = np.array([3, 8, 6, 20, 7])

unionOfSets(A,B)
# Out:
# array([ 1.,  2.,  3.,  5.,  6.,  7.,  8., 20.])

# %% [markdown]
# **Exercise problem 5.** Given an integer array nums, return all the triplets `[nums[i], nums[j], nums[k]]` such that `i != j`, `i != k`, and `j != k`, and `nums[i] + nums[j] + nums[k] == 0`.
#
# Notice that the solution set must not contain duplicate triplets.
#
# https://leetcode.com/problems/3sum/
#
#
# Input: `nums = [-1,0,1,2,-1,-4]`
#
# Output: `[[-1,-1,2],[-1,0,1]]`

# %%
import sys

class Solution:
    def threeSum(self, nums):
        
        result = []
        
        if len(nums) < 2:
            return result
        
        nums.sort()
 
        tempx = sys.maxsize
    
        for i in range(len(nums)):

            if nums[i] == tempx:
                continue
            
            tempx = nums[i]
            
            j = i + 1
            k = len(nums) - 1

            tempy = sys.maxsize
            tempz = sys.maxsize
            
            while(j < k):
                sum = nums[i] + nums[j] + nums[k]
                    
                if sum > 0:
                    k = k - 1
                elif sum < 0:
                    j = j + 1
                elif sum == 0:
                    if nums[j]!= tempy or nums[k]!= tempz:
                        result.append([nums[i],nums[j],nums[k]])
                        tempy = nums[j]
                        tempz = nums[k]
                        
                    j = j + 1
                    k = k - 1
                    
        return result

# %%
solution = Solution()
solution.threeSum([-1,0,1,2,-1,-4])
# Out:
# [[-1, -1, 2], [-1, 0, 1]]
